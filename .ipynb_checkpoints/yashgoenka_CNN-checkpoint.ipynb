# %%
import pandas as pd
import numpy as np
from scipy.signal import find_peaks
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import pandas_ta as ta

from utils.labels import detect_head_and_shoulders, detect_double_bottom, label_patterns, create_windows
from utils.classify_window import classify_window
from utils.forecaster import forecaster
from model.CNN.CNN1D import CNN1D_MultiChannel
from model.CNN.CNN2D import CNN2D_MultiChannel
from trainers.CNN1DTrainer import CNN1DTrainer, TimeSeries1DDataset
from trainers.CNN2DTrainer import CNN2DTrainer, TimeSeries2DDataset

# %%
filepath = "data"
filename = "NIFTY 50_minute_data.csv"
# filename = "NIFTY 50_daily_data.csv"

file = f"{filepath}/{filename}"

df_nifty50_full = pd.read_csv(file)
df_nifty50_full.shape
# Out:
# (932946, 6)

# %%
df_nifty50 = df_nifty50_full[-100000:]

# %%
df_nifty50.loc[:, "ema"] = ta.ema(df_nifty50['close'], length=15)
df_nifty50.loc[:, "rsi"] = ta.rsi(df_nifty50['close'], length=15)
df_nifty50.loc[:, "zscore"] = ta.zscore(df_nifty50['close'], length=15)

df_nifty50.dropna(inplace=True)
df_nifty50.reset_index(drop=True, inplace=True)

# df['EMA'] = ta.ema(df['Close'], length=5)
# df['MACD'] = ta.macd(df['Close'])['MACD_12_26_9']
# df['RSI'] = ta.rsi(df['Close'], length=14)
# Out:
# /tmp/ipykernel_65562/2254231990.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nifty50.loc[:, "ema"] = ta.ema(df_nifty50['close'], length=15)
# /tmp/ipykernel_65562/2254231990.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nifty50.loc[:, "rsi"] = ta.rsi(df_nifty50['close'], length=15)
# /tmp/ipykernel_65562/2254231990.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nifty50.loc[:, "zscore"] = ta.zscore(df_nifty50['close'], length=15)
# /tmp/ipykernel_65562/2254231990.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nifty50.dropna(inplace=True)

# %%
df_nifty50.tail()
# Out:
#                       date      open      high       low     close  volume  \
# 99980  2025-02-07 15:25:00  23569.45  23570.60  23567.00  23568.10       0
# 99981  2025-02-07 15:26:00  23568.10  23570.25  23565.30  23567.40       0
# 99982  2025-02-07 15:27:00  23569.00  23578.35  23565.40  23576.50       0
# 99983  2025-02-07 15:28:00  23577.05  23578.60  23567.45  23568.10       0
# 99984  2025-02-07 15:29:00  23568.10  23571.35  23557.35  23563.15       0
#
#                 ema        rsi    zscore
# 99980  23565.947842  60.730654 -0.686194
# 99981  23566.129362  60.228034 -0.795776
# 99982  23567.425691  64.338901  0.356366
# 99983  23567.509980  58.371835 -0.729732
# 99984  23566.964982  55.142854 -1.212804

# %%
WINDOW_SIZE = 10
PATTERN_LABELS = ['head_and_shoulders', 'double_bottom', 'ascending_triangle', 'none']

# %%
df_nifty_labelled = pd.DataFrame.from_dict(label_patterns(df_nifty50))
# Out:
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)
# /home/yash/Gatech/deeplearning/capstone_project/utils/labels.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   window['window_ema'] = ta.ema(window['close'], length=15)

# %%
df_nifty_labelled.label.value_counts()
# Out:
# label
# double_bottom         58464
# none                  34189
# ascending_triangle     5922
# head_and_shoulders     1400
# Name: count, dtype: int64

# %%
window_tensors, target = create_windows(df_nifty_labelled)
window_tensors[0]
# Out:
# tensor([[2.1739e+04, 2.1731e+04, 5.8809e+01, 1.3655e+00],
#         [2.1742e+04, 2.1733e+04, 6.2139e+01, 1.7213e+00],
#         [2.1736e+04, 2.1733e+04, 5.3502e+01, 7.0540e-01],
#         [2.1740e+04, 2.1734e+04, 5.7230e+01, 1.1048e+00],
#         [2.1734e+04, 2.1734e+04, 5.0537e+01, 1.9853e-01],
#         [2.1741e+04, 2.1735e+04, 5.7162e+01, 1.1267e+00],
#         [2.1743e+04, 2.1736e+04, 5.8968e+01, 1.2573e+00],
#         [2.1741e+04, 2.1737e+04, 5.6189e+01, 8.0460e-01],
#         [2.1744e+04, 2.1737e+04, 5.9106e+01, 1.2907e+00],
#         [2.1741e+04, 2.1738e+04, 5.5001e+01, 5.3924e-01]])

# %%
window_tensors.shape
# Out:
# torch.Size([99975, 10, 4])

# %%
# window_tensors_CNN2D = window_tensors.transpose(0, 2, 1).reshape(-1, 4, 5, 3)

X_train, X_val, y_train, y_val = train_test_split(window_tensors, target, test_size=0.2)

model = CNN1D_MultiChannel(num_classes=4)

trainer = CNN1DTrainer(model, X_train, y_train, X_val, y_val, batch_size=32, lr=1e-3)

trainer.train(num_epochs=10)
trainer.evaluate()

trainer.save_model("models_results/checkpoints/CNN1D_MULTICHANNEL.pt")

predictions = trainer.predict(X_val[:5])
print("Predicted classes:", predictions)

trainer.plot_losses()
# Out:
# /home/yash/Gatech/deeplearning/capstone_project/trainers/CNN1DTrainer.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X = torch.tensor(X, dtype=torch.float32)  # e.g., (N, 15, 4) or (N, 4, 15)
# /home/yash/Gatech/deeplearning/capstone_project/trainers/CNN1DTrainer.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.y = torch.tensor(y, dtype=torch.long)
# torch.Size([79980, 4, 10])
# torch.Size([19995, 4, 10])
# Validation Loss: 0.6701 | Accuracy: 0.8267
# Epoch [1/10], Loss: 0.7867, Accuracy: 0.7551
# Validation Loss: 0.5939 | Accuracy: 0.8681
# Epoch [2/10], Loss: 0.6368, Accuracy: 0.8435
# Validation Loss: 0.5436 | Accuracy: 0.9003
# Epoch [3/10], Loss: 0.5676, Accuracy: 0.8838
# Validation Loss: 0.5186 | Accuracy: 0.9111
# Epoch [4/10], Loss: 0.5299, Accuracy: 0.9057
# Validation Loss: 0.4981 | Accuracy: 0.9245
# Epoch [5/10], Loss: 0.5039, Accuracy: 0.9216
# Validation Loss: 0.4752 | Accuracy: 0.9372
# Epoch [6/10], Loss: 0.4835, Accuracy: 0.9325
# Validation Loss: 0.4712 | Accuracy: 0.9415
# Epoch [7/10], Loss: 0.4691, Accuracy: 0.9413
# Validation Loss: 0.4594 | Accuracy: 0.9471
# Epoch [8/10], Loss: 0.4567, Accuracy: 0.9477
# Validation Loss: 0.4481 | Accuracy: 0.9515
# Epoch [9/10], Loss: 0.4472, Accuracy: 0.9533
# Validation Loss: 0.4437 | Accuracy: 0.9541
# Epoch [10/10], Loss: 0.4401, Accuracy: 0.9572
# Validation Loss: 0.4437 | Accuracy: 0.9541
# ✅ Model saved to: models_results/checkpoints/CNN1D_MULTICHANNEL.pt
# Predicted classes: [1 3 3 0 3]
# /home/yash/Gatech/deeplearning/capstone_project/trainers/CNN1DTrainer.py:127: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X_input, dtype=torch.float32)

# %%
predictions = trainer.predict(X_val[:2])
print("Predicted classes:", list(predictions))
# Out:
# Predicted classes: [1, 3]

# %%
model = CNN2D_MultiChannel(in_channels=4, num_classes=4)
trainer = CNN2DTrainer(model, X_train, y_train, X_val, y_val, batch_size=32, lr=1e-3)
trainer.train(num_epochs=10)
trainer.evaluate()
trainer.save_model("models_results/checkpoints/CNN2D_MULTICHANNEL.pt")
trainer.plot_losses()
# Out:
# /home/yash/Gatech/deeplearning/capstone_project/trainers/CNN2DTrainer.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X = torch.tensor(X, dtype=torch.float32)
# /home/yash/Gatech/deeplearning/capstone_project/trainers/CNN2DTrainer.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(y, dtype=torch.long)
# Validation Loss: 0.8010 | Accuracy: 0.7531
# Epoch [1/10] | Train Loss: 0.8917 | Val Loss: 0.8010 | Train Acc: 0.6935
# Validation Loss: 0.6769 | Accuracy: 0.8220
# Epoch [2/10] | Train Loss: 0.7311 | Val Loss: 0.6769 | Train Acc: 0.7914
# Validation Loss: 0.6293 | Accuracy: 0.8506
# Epoch [3/10] | Train Loss: 0.6516 | Val Loss: 0.6293 | Train Acc: 0.8377
# Validation Loss: 0.5912 | Accuracy: 0.8698
# Epoch [4/10] | Train Loss: 0.6042 | Val Loss: 0.5912 | Train Acc: 0.8648
# Validation Loss: 0.5702 | Accuracy: 0.8859
# Epoch [5/10] | Train Loss: 0.5728 | Val Loss: 0.5702 | Train Acc: 0.8830
# Validation Loss: 0.5653 | Accuracy: 0.8893
# Epoch [6/10] | Train Loss: 0.5499 | Val Loss: 0.5653 | Train Acc: 0.8975
# Validation Loss: 0.5262 | Accuracy: 0.9107
# Epoch [7/10] | Train Loss: 0.5336 | Val Loss: 0.5262 | Train Acc: 0.9062
# Validation Loss: 0.5273 | Accuracy: 0.9102
# Epoch [8/10] | Train Loss: 0.5209 | Val Loss: 0.5273 | Train Acc: 0.9129
# Validation Loss: 0.5153 | Accuracy: 0.9178
# Epoch [9/10] | Train Loss: 0.5120 | Val Loss: 0.5153 | Train Acc: 0.9191
# Validation Loss: 0.5084 | Accuracy: 0.9199
# Epoch [10/10] | Train Loss: 0.5037 | Val Loss: 0.5084 | Train Acc: 0.9219
# Validation Loss: 0.5084 | Accuracy: 0.9199
# ✅ Model saved to: models_results/checkpoints/CNN2D_MULTICHANNEL.pt

# %%
classify_window(window_tensors[1], model_type='2d', model_path="models_results/checkpoints/CNN2D_MULTICHANNEL.pt", PATTERN_LABELS=PATTERN_LABELS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 classify_window(window_tensors[1], model_type='2d', model_path="models_results/checkpoints/CNN2D_MULTICHANNEL.pt", PATTERN_LABELS=PATTERN_LABELS)
#
# NameError: name 'window_tensors' is not defined
